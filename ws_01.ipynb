# %% [markdown]
# # VSB,FEI - Generative AI Workshop
#
# The aim of the workshop is to get an overview of data analysis and deep learning techniques in the generative artificial intelligence (GAI) domain.
#
# * We will use [Python](https://www.python.org/), [Huggingface](https://huggingface.co/) and [Tensorflow](https://www.tensorflow.org/).
#
# **The exercise will cover these topics:**
# * GAI tools for image data using Huggingface models
# * LLM usage for text generating with Huggingface API
# * Vector representation of text data and searching for similar words using vector distance
# * Design of own deep learning model for generating "Harry Potter"-like text using Keras framework from scratch

# %% [markdown]
# # 🔎 What is the Generative AI? 🔎
# * What is usually a *backbone* of these systems?
#
# ![meme01](https://github.com/rasvob/VSB-FEI-Deep-Learning-Exercises/blob/main/images/dl_meme_02.jpg?raw=true)
#
# ## Can you give some examples of usage of such models?
# * 💡 Images, text, audio, video 💡
# * Are these areas somehow interconnected?
#
# ## 🔎 Do you know any famoius models from this area?

# %% [markdown]
# ## Let's install the basic libraries first

# %%
# !pip install transformers diffusers

# %%
# !pip install invisible_watermark transformers accelerate safetensors

# %%
from diffusers import DiffusionPipeline
import torch

pipe = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0", torch_dtype=torch.float16, use_safetensors=True, variant="fp16")
pipe.to("cuda")

# if using torch < 2.0
# pipe.enable_xformers_memory_efficient_attention()

prompt = "An astronaut riding a green horse"

images = pipe(prompt=prompt).images[0]

# %%
prompt = "An astronaut riding a green horse, 3d, unreal engine"

images = pipe(prompt=prompt).images[0]
images.save("tst.png")
images

# %%
prompt = "An knight riding a majestic lion, izometric"

images = pipe(prompt=prompt).images[0]
images.save("tst.png")
images

# %%
prompt = "An knight riding a majestic lion, minecraft"

images = pipe(prompt=prompt).images[0]
images.save("tst.png")
images

# %%
prompt = "An knight riding a majestic lion, hyperrealism"

images = pipe(prompt=prompt).images[0]
images.save("tst.png")
images

# %%
prompt = "An knight with blue eyes riding a majestic lion, hyperrealism"

images = pipe(prompt=prompt).images[0]
images.save("tst.png")
images

# %%
prompt = "An knight with sword riding a majestic lion with armor to battle, 3d, unreal engine, videogame"

images = pipe(prompt=prompt).images[0]
images.save("tst.png")
images

# %%
prompt = "An knight riding a majestic lion with armor to battle, 3d, unreal engine, warcraft"

images = pipe(prompt=prompt).images[0]
images.save("tst.png")
images

# %%
prompt = "An knight riding a majestic lion with armor to battle, 3d, unreal engine, warhammer40k"

images = pipe(prompt=prompt).images[0]
images.save("tst.png")
images

# %%
prompt = "Cute fluffy stuffed teddy bear holds white piece of paper with red hearth symbol, in field of flowers, 2d"

images = pipe(prompt=prompt).images[0]
images.save("tst.png")
images

# %%
prompt = "Cute adorable little bunny waving and smiling greeting me, unreal engine, cozy interior lighting, art station, detailed digital painting, cinematic, character design by mark ryden and pixar and hayao miyazaki, unreal 5, daz, hyper realistic, octane render"

images = pipe(prompt=prompt).images[0]
images.save("tst.png")
images
